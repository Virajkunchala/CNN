# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# %%
data=tf.keras.datasets.fashion_mnist.load_data()

# %%
(X_train,y_train),(X_test,y_test)=data

# %%
# Reshape the data
X_train = X_train.reshape((X_train.shape[0], 28, 28, 1))
X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))

# %%
# Normailising the all pixles by 255 basically all images have the pixles b/w 0 to 255 so
X_train=X_train/255.0
X_test=X_test/255.0

# %%
# Map for human readable class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# printing the train test sizes of the images
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
plt.figure(figsize=(15,15))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
# Building the CNN Model
model = models.Sequential()
model.add(layers.Conv2D(34,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
# model.add(layers.Conv2D(16,(4,4),activation='relu'))
# model.add(layers.MaxPooling2D((2,2)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 34)        340
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 34)       0
#  )
#
# =================================================================
# Total params: 340
# Trainable params: 340
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Add Desne layers after flatting the layers of CNN and add dense layers now its an ANN 
model.add(layers.Flatten())
# Adding dense layers from here ANN will start
model.add(layers.Dense(34,activation='relu'))
# our output categories are ten so
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 34)        340
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 34)       0
#  )
#
#  flatten (Flatten)           (None, 5746)              0
#
#  dense (Dense)               (None, 34)                195398
#
#  dense_1 (Dense)             (None, 10)                350
#
# =================================================================
# Total params: 196,088
# Trainable params: 196,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# callback=tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=0,
#     patience=0,
#     verbose=0,
#     mode="auto",
#     baseline=None,
#     restore_best_weights=False,
# )

# %%
# Compiling the model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])
# history=model.fit(X_train,y_train,epochs=15,validation_data=(X_test,y_test), callbacks=[callback])
history=model.fit(X_train,y_train,epochs=15,validation_data=(X_test,y_test))
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4614 - accuracy: 0.8368 - val_loss: 0.3465 - val_accuracy: 0.8786
# Epoch 2/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3066 - accuracy: 0.8912 - val_loss: 0.3077 - val_accuracy: 0.8886
# Epoch 3/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2679 - accuracy: 0.9031 - val_loss: 0.2948 - val_accuracy: 0.8925
# Epoch 4/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2404 - accuracy: 0.9135 - val_loss: 0.2723 - val_accuracy: 0.9028
# Epoch 5/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2189 - accuracy: 0.9207 - val_loss: 0.2605 - val_accuracy: 0.9062
# Epoch 6/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2011 - accuracy: 0.9268 - val_loss: 0.2605 - val_accuracy: 0.9108
# Epoch 7/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1843 - accuracy: 0.9313 - val_loss: 0.2585 - val_accuracy: 0.9080
# Epoch 8/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1695 - accuracy: 0.9378 - val_loss: 0.2693 - val_accuracy: 0.9058
# Epoch 9/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1578 - accuracy: 0.9412 - val_loss: 0.3260 - val_accuracy: 0.8903
# Epoch 10/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1456 - accuracy: 0.9463 - val_loss: 0.2689 - val_accuracy: 0.9119
# Epoch 11/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1347 - accuracy: 0.9502 - val_loss: 0.2838 - val_accuracy: 0.9114
# Epoch 12/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1240 - accuracy: 0.9543 - val_loss: 0.2863 - val_accuracy: 0.9112
# Epoch 13/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1157 - accuracy: 0.9572 - val_loss: 0.3006 - val_accuracy: 0.9083
# Epoch 14/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1071 - accuracy: 0.9606 - val_loss: 0.3183 - val_accuracy: 0.9069
# Epoch 15/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0981 - accuracy: 0.9643 - val_loss: 0.3157 - val_accuracy: 0.9105
